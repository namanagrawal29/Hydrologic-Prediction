# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('Gadarwara_Q_Compressed.xlsx')
df
# Out:
#            Dates  Year  Month  Day       LRF     Q   Start     End
# 0     1977-06-01  1977      6    1  0.000000  1.60  1977.0  1978.0
# 1     1977-06-02  1977      6    2  0.000000  1.60  1978.0  1979.0
# 2     1977-06-03  1977      6    3  0.000000  1.60  1979.0  1980.0
# 3     1977-06-04  1977      6    4  0.000000  1.60  1980.0  1981.0
# 4     1977-06-05  1977      6    5  0.000000  1.60  1981.0  1982.0
# ...          ...   ...    ...  ...       ...   ...     ...     ...
# 15701 2020-05-27  2020      5   27  0.000000  0.08     NaN     NaN
# 15702 2020-05-28  2020      5   28  0.000000  0.07     NaN     NaN
# 15703 2020-05-29  2020      5   29  0.000000  0.05     NaN     NaN
# 15704 2020-05-30  2020      5   30  0.099727  0.05     NaN     NaN
# 15705 2020-05-31  2020      5   31  0.000000  0.05     NaN     NaN
#
# [15706 rows x 8 columns]

# %%
start = 0
end = 364
k = 2
intervals = []
for i in range(0, 43):
    if k == i:
        interval = (start, end)
        intervals.append(interval)
        k = k + 4
        start = end + 1
        end = end + 366
    elif k != i:
        interval = (start, end)
        intervals.append(interval)
        start = end + 1
        end = end + 365

#df['Q'] = pd.to_numeric(df['Q'], errors='coerce')
sums_array = []

# Loop through each interval, calculate the sum, and append it to the list
for interval in intervals:
    start_index, end_index = interval
    sum_interval = df.loc[start_index:end_index, 'Q'].sum()
    sums_array.append(sum_interval)

if len(sums_array) < len(df):
    diff = len(df) - len(sums_array)
    sums_array.extend([np.nan] * diff)

# Add the sums_array as a new column in the DataFrame
df['sums_column'] = sums_array
# Display the array with sums for each interval
print("Sums Array:", sums_array)
# Out:
# Sums Array: [30945.1, 22543.899999999998, 6429.2, 11613.800000000001, 10461.4, 16125.400000000001, 21321.360000000004, 19073.8, 10744.609999999999, 18721.899999999998, 5814.447, 17753.8023, 12660.684000000001, 25588.773, 8391.785, 13284.279999999999, 16336.61, 35510.693, 10562.579, 7731.261, 15182.992, 9347.203, 42693.73, 8433.172, 6937.342000000001, 14183.92, 18552.2097, 7607.150000000001, 16337.260260979998, 26997.761711182004, 18864.28400776, 9211.347521116, 24902.302943458, 15252.154127836, 14976.238992251998, 25715.101776902004, 34036.39228567, 12339.948704290002, 12320.464149278, 29235.153, 9397.747, 10621.318000000001, 22245.21, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
# ...

# %%
df['LRF'] = pd.to_numeric(df['LRF'], errors='coerce')
sums_LRF = []

for interval in intervals:
    start_index, end_index = interval
    sum_interval = df.loc[start_index:end_index, 'LRF'].sum()
    sums_LRF.append(sum_interval)

if len(sums_LRF) < len(df):
    diff = len(df) - len(sums_LRF)
    sums_LRF.extend([np.nan] * diff)


# Add the sums_array as a new column in the DataFrame
df['SUM LRF'] = sums_LRF
# Display the array with sums for each interval
print("Sums Array:", sums_LRF)
# Out:
# Sums Array: [1559.5448267, 1028.6648516, 825.2821670999999, 978.8783623, 1067.6773432999998, 1003.6566978, 1356.8088627, 1141.4218845, 1121.3108212000002, 1002.8573998999999, 768.5034971, 972.8673101999999, 991.6867098999999, 1384.9522719, 703.9561363999999, 1016.1747962, 1156.1738773, 1620.3831034, 796.3098023, 818.4840071, 1681.0822873999998, 1125.0718304, 1708.4933793, 891.6400894, 1591.2105447, 1048.0187236, 1115.6314019, 916.2117803, 1373.3927862, 946.0713788, 881.5879380000001, 871.8086953999999, 1375.4445529, 1106.2856731, 1233.9130154, 1080.6911016, 1589.2328655999997, 1024.9348824, 999.5756111, 1144.7836896000001, 868.8210027, 729.2920729, 1721.5196176000002, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, n
# ...

# %%
df.to_excel('Sum_LRF&Q_python.xlsx')
df
# Out:
#            Dates  Year  Month  Day       LRF     Q   Start     End  \
# 0     1977-06-01  1977      6    1  0.000000  1.60  1977.0  1978.0
# 1     1977-06-02  1977      6    2  0.000000  1.60  1978.0  1979.0
# 2     1977-06-03  1977      6    3  0.000000  1.60  1979.0  1980.0
# 3     1977-06-04  1977      6    4  0.000000  1.60  1980.0  1981.0
# 4     1977-06-05  1977      6    5  0.000000  1.60  1981.0  1982.0
# ...          ...   ...    ...  ...       ...   ...     ...     ...
# 15701 2020-05-27  2020      5   27  0.000000  0.08     NaN     NaN
# 15702 2020-05-28  2020      5   28  0.000000  0.07     NaN     NaN
# 15703 2020-05-29  2020      5   29  0.000000  0.05     NaN     NaN
# 15704 2020-05-30  2020      5   30  0.099727  0.05     NaN     NaN
# 15705 2020-05-31  2020      5   31  0.000000  0.05     NaN     NaN
#
#        sums_column      SUM LRF
# 0          30945.1  1559.544827
# 1          22543.9  1028.664852
# 2           6429.2   825.282167
# ...
